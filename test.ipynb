# %%
# %run main.py
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# E:\JupyterPro_Pytorch\NewXG\main.py in <module>
#      10 if __name__ == '__main__':
#      11     crawler = Crawler()
# ---> 12     crawler.run()
#
# E:\JupyterPro_Pytorch\NewXG\service\crawler.py in run(self)
#      33     def run(self):
#      34         while True:
# ---> 35             self.crawler()
#      36             time.sleep(60)
#      37
#
# E:\JupyterPro_Pytorch\NewXG\service\crawler.py in crawler(self)
#      54                 continue
#      55
# ---> 56             self.overall_parser(overall_information=overall_information)
#      57             self.province_parser(province_information=province_information)
#      58             self.area_parser(area_information=area_information)
#
# E:\JupyterPro_Pytorch\NewXG\service\crawler.py in overall_parser(self, overall_information)
# ...
